# %% [markdown]
# # 1차 입지선정 순위

# %%
import pandas as pd

# %%
sinan_older_1km = pd.read_csv('datanew/약국_신안_고령인구(1km).csv',encoding='cp949')
sinan_older_1km
# Out:
#      fid  field_1  Unnamed: 0 약국명_y                     주소_y          전화번호  \
# 0      4       67          67  구영약국  전라남도 신안군 암태면 중부로 1820-4  061-271-4287
# 1      4       67          67  구영약국  전라남도 신안군 암태면 중부로 1820-4  061-271-4287
# 2      4       67          67  구영약국  전라남도 신안군 암태면 중부로 1820-4  061-271-4287
# 3      4       67          67  구영약국  전라남도 신안군 암태면 중부로 1820-4  061-271-4287
# 4      4       67          67  구영약국  전라남도 신안군 암태면 중부로 1820-4  061-271-4287
# ..   ...      ...         ...   ...                      ...           ...
# 166   27      594         594  유한약국    전라남도 신안군 임자면 임자로 146,  061-275-8288
# 167   27      594         594  유한약국    전라남도 신안군 임자면 임자로 146,  061-275-8288
# 168   27      594         594  유한약국    전라남도 신안군 임자면 임자로 146,  061-275-8288
# 169   27      594         594  유한약국    전라남도 신안군 임자면 임자로 146,  061-275-8288
# 170   27      594         594  유한약국    전라남도 신안군 임자면 임자로 146,  061-275-8288
#
# ...

# %%
sinan_older_1km = sinan_older_1km.fillna(0)
sinan_older_1km
# Out:
#      fid  field_1  Unnamed: 0 약국명_y                     주소_y          전화번호  \
# 0      4       67          67  구영약국  전라남도 신안군 암태면 중부로 1820-4  061-271-4287
# 1      4       67          67  구영약국  전라남도 신안군 암태면 중부로 1820-4  061-271-4287
# 2      4       67          67  구영약국  전라남도 신안군 암태면 중부로 1820-4  061-271-4287
# 3      4       67          67  구영약국  전라남도 신안군 암태면 중부로 1820-4  061-271-4287
# 4      4       67          67  구영약국  전라남도 신안군 암태면 중부로 1820-4  061-271-4287
# ..   ...      ...         ...   ...                      ...           ...
# 166   27      594         594  유한약국    전라남도 신안군 임자면 임자로 146,  061-275-8288
# 167   27      594         594  유한약국    전라남도 신안군 임자면 임자로 146,  061-275-8288
# 168   27      594         594  유한약국    전라남도 신안군 임자면 임자로 146,  061-275-8288
# 169   27      594         594  유한약국    전라남도 신안군 임자면 임자로 146,  061-275-8288
# 170   27      594         594  유한약국    전라남도 신안군 임자면 임자로 146,  061-275-8288
#
# ...

# %%
sinan_older_1km = sinan_older_1km.groupby(['약국명_y','CLUSTER_ID']).sum('val')
sinan_older_1km
# Out:
#                    fid  field_1  Unnamed: 0      좌표정보(X)      좌표정보(Y)  \
# 약국명_y CLUSTER_ID
# 구영약국  2            208     3484        3484  6557.957874  1811.104162
# 세명약국  0            936    20436       20436  6548.503666  1805.503034
# 유한약국  1           1809    39798       39798  8449.181489  2350.793269
#
#                   CLUSTER_SIZE  ringId  distance    fid_2    lbl    val
# 약국명_y CLUSTER_ID
# 구영약국  2                     52      52     52000  1642563  129.0  129.0
# 세명약국  0                     52      52     52000  1331809  164.0  164.0
# 유한약국  1                     67      67     67000  2116034  235.0  235.0

# %%
damyang_older_1km = pd.read_csv('datanew/담양_클러스터_고령인구(1km).csv',encoding='cp949')
damyang_older_1km
# Out:
#      fid  field_1  Unnamed: 0 약국명_y                    주소_y          전화번호  \
# 0      2       42          42  고서약국  전라남도 담양군 고서면 가사문학로 329  061-381-3338
# 1      2       42          42  고서약국  전라남도 담양군 고서면 가사문학로 329  061-381-3338
# 2      2       42          42  고서약국  전라남도 담양군 고서면 가사문학로 329  061-381-3338
# 3      2       42          42  고서약국  전라남도 담양군 고서면 가사문학로 329  061-381-3338
# 4      2       42          42  고서약국  전라남도 담양군 고서면 가사문학로 329  061-381-3338
# ..   ...      ...         ...   ...                     ...           ...
# 402   43      833         833  한재약국  전라남도 담양군 대전면 추성1로 190,  061-383-2896
# 403   43      833         833  한재약국  전라남도 담양군 대전면 추성1로 190,  061-383-2896
# 404   43      833         833  한재약국  전라남도 담양군 대전면 추성1로 190,  061-383-2896
# 405   43      833         833  한재약국  전라남도 담양군 대전면 추성1로 190,  061-383-2896
# 406   43      833         833  한재약국  전라남도 담양군 대전면 추성1로 190,  061-383-2896
#
#         좌표정보(X)    좌표정보(Y)       월요일 운영       화요일 운영  ... CLUSTER_ID  \
# ...

# %%
damyang_older_1km = damyang_older_1km.fillna(0)

# %%
damyang_older_1km.groupby(['약국명_y','CLUSTER_ID']).sum('val')
# Out:
#                     fid  field_1  Unnamed: 0      좌표정보(X)      좌표정보(Y)  \
# 약국명_y  CLUSTER_ID
# 고서약국   1            138     2898        2898  8761.189012  2430.412854
# 담양유명약국 2            483    10005       10005  8758.294635  2435.824366
# 수북좋은약국 2           1273    28676       28676  8504.346160  2365.246931
# 우리약국   1           1725    39261       39261  8761.211175  2430.401952
# 태원약국   0           2479    50719       50719  8501.492060  2363.538505
# 한재약국   0           2838    54978       54978  8374.551029  2328.235437
#
#                    CLUSTER_SIZE  ringId  distance    fid_2    lbl    val
# 약국명_y  CLUSTER_ID
# 고서약국   1                    138      69     69000  1156312  365.0  365.0
# 담양유명약국 2                    138      69     69000  1389770  518.0  518.0
# 수북좋은약국 2                    134      67     67000  1350670  463.0  463.0
# 우리약국   1                    138      69     69000  1156312  365.0  365.0
# ...

# %%
sinan_older_3km = pd.read_csv('datanew/약국_신안_고령인구(3km).csv',encoding='cp949')
sinan_older_3km
# Out:
#       fid  field_1  Unnamed: 0 약국명_y                     주소_y          전화번호  \
# 0       4       67          67  구영약국  전라남도 신안군 암태면 중부로 1820-4  061-271-4287
# 1       4       67          67  구영약국  전라남도 신안군 암태면 중부로 1820-4  061-271-4287
# 2       4       67          67  구영약국  전라남도 신안군 암태면 중부로 1820-4  061-271-4287
# 3       4       67          67  구영약국  전라남도 신안군 암태면 중부로 1820-4  061-271-4287
# 4       4       67          67  구영약국  전라남도 신안군 암태면 중부로 1820-4  061-271-4287
# ...   ...      ...         ...   ...                      ...           ...
# 1205   27      594         594  유한약국    전라남도 신안군 임자면 임자로 146,  061-275-8288
# 1206   27      594         594  유한약국    전라남도 신안군 임자면 임자로 146,  061-275-8288
# 1207   27      594         594  유한약국    전라남도 신안군 임자면 임자로 146,  061-275-8288
# 1208   27      594         594  유한약국    전라남도 신안군 임자면 임자로 146,  061-275-8288
# 1209   27      594         594  유한약국    전라남도 신안군 임자면 임자로 146,  061-275-8288
#
# ...

# %%
sinan_older_3km = sinan_older_3km.fillna(0)

# %%
sinan_older_3km.groupby('약국명_y').sum('val')
# Out:
#          fid  field_1  Unnamed: 0       좌표정보(X)       좌표정보(Y)  CLUSTER_ID  \
# 약국명_y
# 구영약국    1540    25795       25795  48554.111183  13409.136587         770
# 세명약국    7632   166632      166632  53395.491427  14721.793973           0
# 유한약국   10827   238194      238194  50568.981746  14069.673147         401
#
#        CLUSTER_SIZE  ringId  distance     fid_2    lbl    val
# 약국명_y
# 구영약국            385     385   1155000  12114389  416.0  416.0
# 세명약국            424     424   1272000  10872407  528.0  528.0
# 유한약국            401     401   1203000  12574199  620.0  620.0

# %%
damyang_older_3km = pd.read_csv('datanew/담양_클러스터_고령인구(3km).csv',encoding='cp949')
damyang_older_3km
# Out:
#       fid  field_1  Unnamed: 0 약국명_y                    주소_y          전화번호  \
# 0       2       42          42  고서약국  전라남도 담양군 고서면 가사문학로 329  061-381-3338
# 1       2       42          42  고서약국  전라남도 담양군 고서면 가사문학로 329  061-381-3338
# 2       2       42          42  고서약국  전라남도 담양군 고서면 가사문학로 329  061-381-3338
# 3       2       42          42  고서약국  전라남도 담양군 고서면 가사문학로 329  061-381-3338
# 4       2       42          42  고서약국  전라남도 담양군 고서면 가사문학로 329  061-381-3338
# ...   ...      ...         ...   ...                     ...           ...
# 2950   43      833         833  한재약국  전라남도 담양군 대전면 추성1로 190,  061-383-2896
# 2951   43      833         833  한재약국  전라남도 담양군 대전면 추성1로 190,  061-383-2896
# 2952   43      833         833  한재약국  전라남도 담양군 대전면 추성1로 190,  061-383-2896
# 2953   43      833         833  한재약국  전라남도 담양군 대전면 추성1로 190,  061-383-2896
# 2954   43      833         833  한재약국  전라남도 담양군 대전면 추성1로 190,  061-383-2896
#
# ...

# %%
damyang_older_3km = damyang_older_3km.fillna(0)

# %%
damyang_older_3km.groupby('약국명_y').sum('val')
# Out:
#           fid  field_1  Unnamed: 0       좌표정보(X)       좌표정보(Y)  CLUSTER_ID  \
# 약국명_y
# 고서약국      908    19068       19068  57646.084225  15991.412114         454
# 담양유명약국   3514    72790       72790  63719.766763  17721.504805        1004
# 수북좋은약국   9538   214856      214856  63719.130929  17721.700886        1004
# 우리약국    11450   260602      260602  58154.126350  16132.233249         458
# 태원약국    19277   394397      394397  66108.617365  18379.157626           0
# 한재약국    22274   431494      431494  65727.536862  18273.120551           0
#
#         CLUSTER_SIZE  ringId  distance     fid_2     lbl     val
# 약국명_y
# 고서약국             908     454   1362000   7629154  1488.0  1488.0
# 담양유명약국          1004     502   1506000   9561756  2043.0  2043.0
# 수북좋은약국          1004     502   1506000   9561099  1984.0  1984.0
# 우리약국             916     458   1374000   7698177  1495.0  1495.0
# 태원약국            1042     521   1563000  12594360  1664.0  1664.0
# ...

# %%
sinan_access = pd.read_csv('datanew/약국_신안_접근성.csv',encoding='cp949')
sinan_access
# Out:
#    fid  field_1  Unnamed: 0 약국명_y                      주소_y          전화번호  \
# 0    4       67          67  구영약국   전라남도 신안군 암태면 중부로 1820-4  061-271-4287
# 1   18      393         393  세명약국  전라남도 신안군 비금면 송치길 155-19,  061-275-7588
# 2   27      594         594  유한약국     전라남도 신안군 임자면 임자로 146,  061-275-8288
#
#       좌표정보(X)    좌표정보(Y)       월요일 운영       화요일 운영  ...       목요일 운영  \
# 0  126.114575  34.828926  08:00~20:00  08:00~20:00  ...  08:00~20:00
# 1  125.932763  34.721212  08:00~21:00  08:00~21:00  ...  08:00~21:00
# 2  126.107186  35.086467  08:00~18:00  08:00~18:00  ...  08:00~18:00
#
#         금요일 운영       토요일 운영 일요일 운영 공휴일 운영 CLUSTER_ID  CLUSTER_SIZE  ringId  \
# 0  08:00~20:00  08:00~13:00      -      -          2             1       1
# 1  08:00~21:00  08:00~17:00      -      -          0             1       1
# 2  08:00~18:00  08:00~13:00      -      -          1             1       1
#
#    distance  NUMPOINTS
# 0      1000          8
# 1      1000          6
# ...
